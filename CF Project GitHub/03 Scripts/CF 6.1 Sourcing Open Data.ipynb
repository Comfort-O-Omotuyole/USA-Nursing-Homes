# %% [markdown]
# # CF Project 6.1: Data Wrangling and Consistency Checks
# ## This script contains the following topics
# ### 01. Importing Libraries and Data
# ### 02. Data Wrangling and Consistency Checks
# #### a) Dropping unnecessary columns
# #### b) Check for mixed data types
# #### c) Missing Values
# #### d) Duplicates
# #### e) Dropping more unnecessary columns
# ### 03. Export DataFrame as .csv file

# %% [markdown]
# # 01. Importing Libraries and File

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path folder
path =r'C:\Users\olufunsoo\Documents\CFProject'

# %%
# Import file 'Provider_Info Nursing' as 'df_nurs'
df_nurs = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Provider_Info Nursing.csv'), index_col = False)

# %%
# Checking output
df_nurs.head(5)
# Out:
#    index Federal Provider Number  \
# 0      0                   15019
# 1      1                   15113
# 2      2                   15112
# 3      3                   15114
# 4      4                   15123
#
#                                      Provider Name  \
# 0  MERRY WOOD LODGE CARE AND REHABILITATION CENTER
# 1                                RIVER CITY CENTER
# 2  MAGNOLIA HAVEN HEALTH AND REHABILITATION CENTER
# 3                   SHADESCREST HEALTH CARE CENTER
# 4                   WASHINGTON COUNTY NURSING HOME
#
#                    Provider Address Provider City Provider State  \
# 0                       P O BOX 130        ELMORE             AL
# 1  1350 FOURTEENTH AVENUE SOUTHEAST       DECATUR             AL
# 2                 603 WRIGHT STREET      TUSKEGEE             AL
# 3              331 WEST 25TH STREET        JASPER             AL
# 4          14600 ST STEPHENS AVENUE        CHATOM             AL
#
#    Provider Zip Code  Provider Phone Number  Provider SSA County Code  \
# 0              36025             3345678484                       250
# 1              35601             2563556911                       510
# 2              36083             3347274960                       430
# 3              35502             2053849086                       630
# 4              36518             2518476412                       640
#
#   Provider County Name  ... Cycle 3 Total Health Score  \
# 0               Elmore  ...                       24.0
# 1               Morgan  ...                       40.0
# 2                Macon  ...                       16.0
# 3               Walker  ...                       52.0
# 4           Washington  ...                       20.0
#
#    Total Weighted Health Survey Score  Number of Facility Reported Incidents  \
# 0                              22.667                                      0
# 1                              48.667                                      0
# 2                              15.333                                      0
# 3                              25.333                                      0
# 4                              13.333                                      0
#
#   Number of Substantiated Complaints  Number of Fines  \
# 0                                  1                1
# 1                                  3                1
# 2                                  0                0
# 3                                  3                1
# 4                                  0                0
#
#   Total Amount of Fines in Dollars Number of Payment Denials  \
# 0                       $6,692.00                          0
# 1                       $6,045.00                          0
# 2                           $0.00                          0
# 3                     $189,763.00                          0
# 4                           $0.00                          0
#
#    Total Number of Penalties  \
# 0                          1
# 1                          1
# 2                          0
# 3                          1
# 4                          0
#
#                                             Location  Processing Date
# 0                             130 ELMORE\nAL 36025\n         9/1/2016
# 1  1350 FOURTEENTH AVENUE SOUTHEAST\nDECATUR, AL ...         9/1/2016
# 2  603 WRIGHT STREET\nTUSKEGEE, AL 36083\n(32.432...         9/1/2016
# 3  331 WEST 25TH STREET\nJASPER, AL 35502\n(33.82...         9/1/2016
# 4  14600 ST STEPHENS AVENUE\nCHATOM, AL 36518\n(3...         9/1/2016
#
# [5 rows x 82 columns]

# %%
df_nurs.shape
# Out:
# (15640, 82)

# %%
df_nurs.columns
# Out:
# Index(['index', 'Federal Provider Number', 'Provider Name', 'Provider Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Provider Phone Number', 'Provider SSA County Code',
#        'Provider County Name', 'Ownership Type', 'Number of Certified Beds',
#        'Number of Residents in Certified Beds', 'Provider Type',
#        'Provider Resides in Hospital', 'Legal Business Name',
#        'Date First Approved to Provide Medicare and Medicaid services',
#        'Continuing Care Retirement Community', 'Special Focus Facility',
#        'Most Recent Health Inspection More Than 2 Years Ago',
#        'Provider Changed Ownership in Last 12 Months',
#        'With a Resident and Family Council',
#        'Automatic Sprinkler Systems in All Required Areas', 'Overall Rating',
#        'Overall Rating Footnote', 'Health Inspection Rating',
#        'Health Inspection Rating Footnote', 'QM Rating', 'QM Rating Footnote',
#        'Staffing Rating', 'Staffing Rating Footnote', 'RN Staffing Rating',
#        'RN Staffing Rating Footnote', 'Reported Staffing Footnote',
#        'Physical Therapist Staffing Footnote',
#        'Reported CNA Staffing Hours per Resident per Day',
#        'Reported LPN Staffing Hours per Resident per Day',
#        'Reported RN Staffing Hours per Resident per Day',
#        'Reported Licensed Staffing Hours per Resident per Day',
#        'Reported Total Nurse Staffing Hours per Resident per Day',
#        'Reported Physical Therapist Staffing Hours per Resident Per Day',
#        'Expected CNA Staffing Hours per Resident per Day',
#        'Expected LPN Staffing Hours per Resident per Day',
#        'Expected RN Staffing Hours per Resident per Day',
#        'Expected Total Nurse Staffing Hours per Resident per Day',
#        'Adjusted CNA Staffing Hours per Resident per Day',
#        'Adjusted LPN Staffing Hours per Resident per Day',
#        'Adjusted RN Staffing Hours per Resident per Day',
#        'Adjusted Total Nurse Staffing Hours per Resident per Day',
#        'Cycle 1 Total Number of Health Deficiencies',
#        'Cycle 1 Number of Standard Health Deficiencies',
#        'Cycle 1 Number of Complaint Health Deficiencies',
#        'Cycle 1 Health Deficiency Score',
#        'Cycle 1 Standard Survey Health Date',
#        'Cycle 1 Number of Health Revisits', 'Cycle 1 Health Revisit Score',
#        'Cycle 1 Total Health Score',
#        'Cycle 2 Total Number of Health Deficiencies',
#        'Cycle 2 Number of Standard Health Deficiencies',
#        'Cycle 2 Number of Complaint Health Deficiencies',
#        'Cycle 2 Health Deficiency Score',
#        'Cycle 2 Standard Health Survey Date',
#        'Cycle 2 Number of Health Revisits', 'Cycle 2 Health Revisit Score',
#        'Cycle 2 Total Health Score',
#        'Cycle 3 Total Number of Health Deficiencies',
#        'Cycle 3 Number of Standard Health Deficiencies',
#        'Cycle 3 Number of Complaint Health Deficiencies',
#        'Cycle 3 Health Deficiency Score',
#        'Cycle 3 Standard Health Survey Date',
#        'Cycle 3 Number of Health Revisits', 'Cycle 3 Health Revisit Score',
#        'Cycle 3 Total Health Score', 'Total Weighted Health Survey Score',
#        'Number of Facility Reported Incidents',
#        'Number of Substantiated Complaints', 'Number of Fines',
#        'Total Amount of Fines in Dollars', 'Number of Payment Denials',
#        'Total Number of Penalties', 'Location', 'Processing Date'],
#       dtype='object')

# %%
df_nurs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15640 entries, 0 to 15639
# Data columns (total 82 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   index                                                            15640 non-null  int64
#  1   Federal Provider Number                                          15640 non-null  object
#  2   Provider Name                                                    15640 non-null  object
#  3   Provider Address                                                 15640 non-null  object
#  4   Provider City                                                    15640 non-null  object
#  5   Provider State                                                   15640 non-null  object
#  6   Provider Zip Code                                                15640 non-null  int64
#  7   Provider Phone Number                                            15640 non-null  int64
#  8   Provider SSA County Code                                         15640 non-null  int64
#  9   Provider County Name                                             15640 non-null  object
#  10  Ownership Type                                                   15640 non-null  object
#  11  Number of Certified Beds                                         15640 non-null  int64
#  12  Number of Residents in Certified Beds                            15640 non-null  int64
#  13  Provider Type                                                    15640 non-null  object
#  14  Provider Resides in Hospital                                     15640 non-null  bool
#  15  Legal Business Name                                              15640 non-null  object
#  16  Date First Approved to Provide Medicare and Medicaid services    15640 non-null  object
#  17  Continuing Care Retirement Community                             15640 non-null  bool
#  18  Special Focus Facility                                           15640 non-null  bool
#  19  Most Recent Health Inspection More Than 2 Years Ago              15640 non-null  bool
#  20  Provider Changed Ownership in Last 12 Months                     15640 non-null  bool
#  21  With a Resident and Family Council                               15042 non-null  object
#  22  Automatic Sprinkler Systems in All Required Areas                15640 non-null  object
#  23  Overall Rating                                                   15505 non-null  float64
#  24  Overall Rating Footnote                                          135 non-null    object
#  25  Health Inspection Rating                                         15505 non-null  float64
#  26  Health Inspection Rating Footnote                                135 non-null    object
#  27  QM Rating                                                        15477 non-null  float64
#  28  QM Rating Footnote                                               163 non-null    object
#  29  Staffing Rating                                                  15198 non-null  float64
#  30  Staffing Rating Footnote                                         442 non-null    object
#  31  RN Staffing Rating                                               15198 non-null  float64
#  32  RN Staffing Rating Footnote                                      442 non-null    object
#  33  Reported Staffing Footnote                                       396 non-null    object
#  34  Physical Therapist Staffing Footnote                             398 non-null    object
#  35  Reported CNA Staffing Hours per Resident per Day                 15244 non-null  float64
#  36  Reported LPN Staffing Hours per Resident per Day                 15244 non-null  float64
#  37  Reported RN Staffing Hours per Resident per Day                  15244 non-null  float64
#  38  Reported Licensed Staffing Hours per Resident per Day            15244 non-null  float64
#  39  Reported Total Nurse Staffing Hours per Resident per Day         15244 non-null  float64
#  40  Reported Physical Therapist Staffing Hours per Resident Per Day  15242 non-null  float64
#  41  Expected CNA Staffing Hours per Resident per Day                 15571 non-null  float64
#  42  Expected LPN Staffing Hours per Resident per Day                 15571 non-null  float64
#  43  Expected RN Staffing Hours per Resident per Day                  15571 non-null  float64
#  44  Expected Total Nurse Staffing Hours per Resident per Day         15571 non-null  float64
#  45  Adjusted CNA Staffing Hours per Resident per Day                 15198 non-null  float64
#  46  Adjusted LPN Staffing Hours per Resident per Day                 15198 non-null  float64
#  47  Adjusted RN Staffing Hours per Resident per Day                  15198 non-null  float64
#  48  Adjusted Total Nurse Staffing Hours per Resident per Day         15198 non-null  float64
#  49  Cycle 1 Total Number of Health Deficiencies                      15505 non-null  float64
#  50  Cycle 1 Number of Standard Health Deficiencies                   15505 non-null  float64
#  51  Cycle 1 Number of Complaint Health Deficiencies                  15505 non-null  float64
#  52  Cycle 1 Health Deficiency Score                                  15505 non-null  float64
#  53  Cycle 1 Standard Survey Health Date                              15505 non-null  object
#  54  Cycle 1 Number of Health Revisits                                15505 non-null  float64
#  55  Cycle 1 Health Revisit Score                                     15505 non-null  float64
#  56  Cycle 1 Total Health Score                                       15505 non-null  float64
#  57  Cycle 2 Total Number of Health Deficiencies                      15505 non-null  float64
#  58  Cycle 2 Number of Standard Health Deficiencies                   15505 non-null  float64
#  59  Cycle 2 Number of Complaint Health Deficiencies                  15505 non-null  float64
#  60  Cycle 2 Health Deficiency Score                                  15505 non-null  float64
#  61  Cycle 2 Standard Health Survey Date                              15505 non-null  object
#  62  Cycle 2 Number of Health Revisits                                15505 non-null  float64
#  63  Cycle 2 Health Revisit Score                                     15505 non-null  float64
#  64  Cycle 2 Total Health Score                                       15505 non-null  float64
#  65  Cycle 3 Total Number of Health Deficiencies                      15362 non-null  float64
#  66  Cycle 3 Number of Standard Health Deficiencies                   15362 non-null  float64
#  67  Cycle 3 Number of Complaint Health Deficiencies                  15362 non-null  float64
#  68  Cycle 3 Health Deficiency Score                                  15362 non-null  float64
#  69  Cycle 3 Standard Health Survey Date                              15362 non-null  object
#  70  Cycle 3 Number of Health Revisits                                15362 non-null  float64
#  71  Cycle 3 Health Revisit Score                                     15362 non-null  float64
#  72  Cycle 3 Total Health Score                                       15362 non-null  float64
#  73  Total Weighted Health Survey Score                               15505 non-null  float64
#  74  Number of Facility Reported Incidents                            15640 non-null  int64
#  75  Number of Substantiated Complaints                               15640 non-null  int64
#  76  Number of Fines                                                  15640 non-null  int64
#  77  Total Amount of Fines in Dollars                                 15640 non-null  object
#  78  Number of Payment Denials                                        15640 non-null  int64
#  79  Total Number of Penalties                                        15640 non-null  int64
#  80  Location                                                         15613 non-null  object
#  81  Processing Date                                                  15640 non-null  object
# dtypes: bool(5), float64(41), int64(11), object(25)
# memory usage: 9.3+ MB

# %% [markdown]
# # 02. Data Wrangling and Consistency Checks

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df_nurs = df_nurs.drop(columns = ['index', 'Provider City', 'Provider County Name', 'Provider Address', 'Provider Zip Code', 'Provider Phone Number', 'Provider SSA County Code', 'Legal Business Name', 'Location'])

# %% [markdown]
# ## Check for mixed data types

# %%
# Check for mixed types
for col in df_nurs.columns.tolist():
  weird = (df_nurs[[col]].applymap(type) != df_nurs[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_nurs[weird]) > 0:
    print (col)
# Out:
# With a Resident and Family Council
# Overall Rating Footnote
# Health Inspection Rating Footnote
# QM Rating Footnote
# Staffing Rating Footnote
# RN Staffing Rating Footnote
# Reported Staffing Footnote
# Physical Therapist Staffing Footnote
# Cycle 1 Standard Survey Health Date
# Cycle 2 Standard Health Survey Date
# Cycle 3 Standard Health Survey Date

# %%
# Correcting mixed data type by changing all data to string
df_nurs['Overall Rating Footnote'] = df_nurs['Overall Rating Footnote'].astype
df_nurs['Health Inspection Rating Footnote'] = df_nurs['Health Inspection Rating Footnote'].astype
df_nurs['RN Staffing Rating Footnote'] = df_nurs['RN Staffing Rating Footnote'].astype
df_nurs['Physical Therapist Staffing Footnote'] = df_nurs['Physical Therapist Staffing Footnote'].astype

# %%
# Correcting mixed data type by changing all data to string
df_nurs['Reported Staffing Footnote'] = df_nurs['Reported Staffing Footnote'].astype
df_nurs['QM Rating Footnote'] = df_nurs['QM Rating Footnote'].astype
df_nurs['Staffing Rating Footnote'] = df_nurs['Staffing Rating Footnote'].astype
df_nurs['Cycle 1 Standard Survey Health Date'] = df_nurs['Cycle 1 Standard Survey Health Date'].astype
df_nurs['Cycle 2 Standard Health Survey Date'] = df_nurs['Cycle 2 Standard Health Survey Date'].astype
df_nurs['Cycle 3 Standard Health Survey Date'] = df_nurs['Cycle 3 Standard Health Survey Date'].astype
df_nurs['With a Resident and Family Council'] = df_nurs['With a Resident and Family Council'].astype

# %%
# Checking output
for col in df_nurs.columns.tolist():
  weird = (df_nurs[[col]].applymap(type) != df_nurs[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_nurs[weird]) > 0:
    print (col)

# %% [markdown]
# ## Missing Values

# %%
# Finding missing values
df_nurs.isnull().sum()
# Out:
# Federal Provider Number             0
# Provider Name                       0
# Provider State                      0
# Ownership Type                      0
# Number of Certified Beds            0
#                                    ..
# Number of Fines                     0
# Total Amount of Fines in Dollars    0
# Number of Payment Denials           0
# Total Number of Penalties           0
# Processing Date                     0
# Length: 73, dtype: int64

# %%
print (df_nurs.isnull())
# Out:
#        Federal Provider Number  Provider Name  Provider State  Ownership Type  \
# 0                        False          False           False           False
# 1                        False          False           False           False
# 2                        False          False           False           False
# 3                        False          False           False           False
# 4                        False          False           False           False
# ...                        ...            ...             ...             ...
# 15635                    False          False           False           False
# 15636                    False          False           False           False
# 15637                    False          False           False           False
# 15638                    False          False           False           False
# 15639                    False          False           False           False
#
#        Number of Certified Beds  Number of Residents in Certified Beds  \
# 0                         False                                  False
# 1                         False                                  False
# 2                         False                                  False
# 3                         False                                  False
# 4                         False                                  False
# ...                         ...                                    ...
# 15635                     False                                  False
# 15636                     False                                  False
# 15637                     False                                  False
# 15638                     False                                  False
# 15639                     False                                  False
#
#        Provider Type  Provider Resides in Hospital  \
# 0              False                         False
# 1              False                         False
# 2              False                         False
# 3              False                         False
# 4              False                         False
# ...              ...                           ...
# 15635          False                         False
# 15636          False                         False
# 15637          False                         False
# 15638          False                         False
# 15639          False                         False
#
#        Date First Approved to Provide Medicare and Medicaid services  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 15635                                              False
# 15636                                              False
# 15637                                              False
# 15638                                              False
# 15639                                              False
#
#        Continuing Care Retirement Community  ...  \
# 0                                     False  ...
# 1                                     False  ...
# 2                                     False  ...
# 3                                     False  ...
# 4                                     False  ...
# ...                                     ...  ...
# 15635                                 False  ...
# 15636                                 False  ...
# 15637                                 False  ...
# 15638                                 False  ...
# 15639                                 False  ...
#
#        Cycle 3 Health Revisit Score  Cycle 3 Total Health Score  \
# 0                             False                       False
# 1                             False                       False
# 2                             False                       False
# 3                             False                       False
# 4                             False                       False
# ...                             ...                         ...
# 15635                          True                        True
# 15636                          True                        True
# 15637                          True                        True
# 15638                          True                        True
# 15639                          True                        True
#
#        Total Weighted Health Survey Score  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 15635                               False
# 15636                               False
# 15637                                True
# 15638                                True
# 15639                               False
#
#        Number of Facility Reported Incidents  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 15635                                  False
# 15636                                  False
# 15637                                  False
# 15638                                  False
# 15639                                  False
#
#        Number of Substantiated Complaints  Number of Fines  \
# 0                                   False            False
# 1                                   False            False
# 2                                   False            False
# 3                                   False            False
# 4                                   False            False
# ...                                   ...              ...
# 15635                               False            False
# 15636                               False            False
# 15637                               False            False
# 15638                               False            False
# 15639                               False            False
#
#        Total Amount of Fines in Dollars  Number of Payment Denials  \
# 0                                 False                      False
# 1                                 False                      False
# 2                                 False                      False
# 3                                 False                      False
# 4                                 False                      False
# ...                                 ...                        ...
# 15635                             False                      False
# 15636                             False                      False
# 15637                             False                      False
# 15638                             False                      False
# 15639                             False                      False
#
#        Total Number of Penalties  Processing Date
# 0                          False            False
# 1                          False            False
# 2                          False            False
# 3                          False            False
# 4                          False            False
# ...                          ...              ...
# 15635                      False            False
# 15636                      False            False
# 15637                      False            False
# 15638                      False            False
# 15639                      False            False
#
# [15640 rows x 73 columns]

# %%
# Creating a subset of missing values
df_nan = df_nurs[df_nurs['QM Rating'].isnull() == True]

# %%
df_nan
# Out:
#       Federal Provider Number  \
# 53                     04A326
# 154                    155844
# 155                    155846
# 183                    165614
# 228                    175551
# ...                       ...
# 15625                  676390
# 15627                  676392
# 15630                  676386
# 15637                  676391
# 15638                  676377
#
#                                            Provider Name Provider State  \
# 53                   COLONEL GLENN HEALTH AND REHAB, LLC             AR
# 154                           SYMPHONY OF CHESTERTON LLC             IN
# 155                       GREEN HOUSE COTTAGES OF CARMEL             IN
# 183                              ROSE HAVEN NURSING HOME             IA
# 228                      THE HEALTHCARE RESORT OF OLATHE             KS
# ...                                                  ...            ...
# 15625                            LEXINGTON MEDICAL LODGE             TX
# 15627  LEGEND OAKS HEALTHCARE AND REHABILITATION - NE...             TX
# 15630                                WEST REST HAVEN INC             TX
# 15637                                   WINDSOR CALALLEN             TX
# 15638                           RELIANT DALLAS SUB-ACUTE             TX
#
#                                Ownership Type  Number of Certified Beds  \
# 53                   For profit - Corporation                       120
# 154                  For profit - Corporation                        70
# 155                  For profit - Corporation                        72
# 183                   For profit - Individual                        58
# 228                  For profit - Corporation                        70
# ...                                       ...                       ...
# 15625                For profit - Corporation                       128
# 15627  For profit - Limited Liability company                        75
# 15630                For profit - Corporation                       120
# 15637                For profit - Partnership                       120
# 15638                For profit - Partnership                        20
#
#        Number of Residents in Certified Beds          Provider Type  \
# 53                                         7               Medicaid
# 154                                        2  Medicare and Medicaid
# 155                                        3  Medicare and Medicaid
# 183                                       50  Medicare and Medicaid
# 228                                        2  Medicare and Medicaid
# ...                                      ...                    ...
# 15625                                      3  Medicare and Medicaid
# 15627                                      2  Medicare and Medicaid
# 15630                                      3  Medicare and Medicaid
# 15637                                      3  Medicare and Medicaid
# 15638                                      3               Medicare
#
#        Provider Resides in Hospital  \
# 53                            False
# 154                           False
# 155                           False
# 183                           False
# 228                           False
# ...                             ...
# 15625                         False
# 15627                         False
# 15630                         False
# 15637                         False
# 15638                         False
#
#       Date First Approved to Provide Medicare and Medicaid services  \
# 53                                             5/26/2016
# 154                                             3/9/2016
# 155                                             6/1/2016
# 183                                            3/17/2016
# 228                                             1/9/2016
# ...                                                  ...
# 15625                                          9/21/2015
# 15627                                         10/16/2015
# 15630                                          8/25/2015
# 15637                                         11/12/2015
# 15638                                          3/19/2015
#
#        Continuing Care Retirement Community  ...  \
# 53                                    False  ...
# 154                                   False  ...
# 155                                   False  ...
# 183                                   False  ...
# 228                                   False  ...
# ...                                     ...  ...
# 15625                                 False  ...
# 15627                                 False  ...
# 15630                                 False  ...
# 15637                                 False  ...
# 15638                                 False  ...
#
#        Cycle 3 Health Revisit Score  Cycle 3 Total Health Score  \
# 53                              NaN                         NaN
# 154                             NaN                         NaN
# 155                             NaN                         NaN
# 183                             NaN                         NaN
# 228                             NaN                         NaN
# ...                             ...                         ...
# 15625                           NaN                         NaN
# 15627                           NaN                         NaN
# 15630                           NaN                         NaN
# 15637                           NaN                         NaN
# 15638                           NaN                         NaN
#
#        Total Weighted Health Survey Score  \
# 53                                    NaN
# 154                                   NaN
# 155                                   NaN
# 183                                   NaN
# 228                                   NaN
# ...                                   ...
# 15625                                 NaN
# 15627                                 NaN
# 15630                                 NaN
# 15637                                 NaN
# 15638                                 NaN
#
#       Number of Facility Reported Incidents  \
# 53                                        0
# 154                                       0
# 155                                       0
# 183                                       0
# 228                                       0
# ...                                     ...
# 15625                                     0
# 15627                                     0
# 15630                                     0
# 15637                                     0
# 15638                                     0
#
#       Number of Substantiated Complaints  Number of Fines  \
# 53                                     0                0
# 154                                    3                0
# 155                                    0                0
# 183                                    0                0
# 228                                    0                0
# ...                                  ...              ...
# 15625                                  0                0
# 15627                                  0                0
# 15630                                  0                0
# 15637                                  0                0
# 15638                                  0                0
#
#       Total Amount of Fines in Dollars  Number of Payment Denials  \
# 53                              $0.00                           0
# 154                             $0.00                           0
# 155                             $0.00                           0
# 183                             $0.00                           0
# 228                             $0.00                           0
# ...                                ...                        ...
# 15625                           $0.00                           0
# 15627                           $0.00                           0
# 15630                           $0.00                           0
# 15637                           $0.00                           0
# 15638                           $0.00                           0
#
#       Total Number of Penalties  Processing Date
# 53                            0         9/1/2016
# 154                           0         9/1/2016
# 155                           0         9/1/2016
# 183                           0         9/1/2016
# 228                           0         9/1/2016
# ...                         ...              ...
# 15625                         0         9/1/2016
# 15627                         0         9/1/2016
# 15630                         0         9/1/2016
# 15637                         0         9/1/2016
# 15638                         0         9/1/2016
#
# [163 rows x 73 columns]

# %%
df_nurs.shape
# Out:
# (15640, 73)

# %%
# Dropping missing values
df_nurs.dropna(inplace = True)

# %%
# Checking output
df_nurs.shape
# Out:
# (15050, 73)

# %%
# Checking output - Creating a subset of missing values
df_nan = df_nurs[df_nurs['QM Rating'].isnull() == True]

# %%
df_nan
# Out:
# Empty DataFrame
# Columns: [Federal Provider Number, Provider Name, Provider State, Ownership Type, Number of Certified Beds, Number of Residents in Certified Beds, Provider Type, Provider Resides in Hospital, Date First Approved to Provide Medicare and Medicaid services, Continuing Care Retirement Community, Special Focus Facility, Most Recent Health Inspection More Than 2 Years Ago, Provider Changed Ownership in Last 12 Months, With a Resident and Family Council, Automatic Sprinkler Systems in All Required Areas, Overall Rating, Overall Rating Footnote, Health Inspection Rating, Health Inspection Rating Footnote, QM Rating, QM Rating Footnote, Staffing Rating, Staffing Rating Footnote, RN Staffing Rating, RN Staffing Rating Footnote, Reported Staffing Footnote, Physical Therapist Staffing Footnote, Reported CNA Staffing Hours per Resident per Day, Reported LPN Staffing Hours per Resident per Day, Reported RN Staffing Hours per Resident per Day, Reported Licensed Staffing Hours per Resident per Day, Reported Total Nurse Staffing Hours per Resident per Day, Reported Physical Therapist Staffing Hours per Resident Per Day, Expected CNA Staffing Hours per Resident per Day, Expected LPN Staffing Hours per Resident per Day, Expected RN Staffing Hours per Resident per Day, Expected Total Nurse Staffing Hours per Resident per Day, Adjusted CNA Staffing Hours per Resident per Day, Adjusted LPN Staffing Hours per Resident per Day, Adjusted RN Staffing Hours per Resident per Day, Adjusted Total Nurse Staffing Hours per Resident per Day, Cycle 1 Total Number of Health Deficiencies, Cycle 1 Number of Standard Health Deficiencies, Cycle 1 Number of Complaint Health Deficiencies, Cycle 1 Health Deficiency Score, Cycle 1 Standard Survey Health Date, Cycle 1 Number of Health Revisits, Cycle 1 Health Revisit Score, Cycle 1 Total Health Score, Cycle 2 Total Number of Health Deficiencies, Cycle 2 Number of Standard Health Deficiencies, Cycle 2 Number of Complaint Health Deficiencies, Cycle 2 Health Deficiency Score, Cycle 2 Standard Health Survey Date, Cycle 2 Number of Health Revisits, Cycle 2 Health Revisit Score, Cycle 2 Total Health Score, Cycle 3 Total Number of Health Deficiencies, Cycle 3 Number of Standard Health Deficiencies, Cycle 3 Number of Complaint Health Deficiencies, Cycle 3 Health Deficiency Score, Cycle 3 Standard Health Survey Date, Cycle 3 Number of Health Revisits, Cycle 3 Health Revisit Score, Cycle 3 Total Health Score, Total Weighted Health Survey Score, Number of Facility Reported Incidents, Number of Substantiated Complaints, Number of Fines, Total Amount of Fines in Dollars, Number of Payment Denials, Total Number of Penalties, Processing Date]
# Index: []
#
# [0 rows x 73 columns]

# %%
df_nurs = df_nurs.drop(df_nurs[df_nurs['Overall Rating Footnote'] == 'Too New to Rate'].index)

# %%
df_nurs.shape
# Out:
# (15050, 73)

# %% [markdown]
# ## Duplicates

# %%
# Finding duplicates
df_dups = df_nurs[df_nurs.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Federal Provider Number, Provider Name, Provider State, Ownership Type, Number of Certified Beds, Number of Residents in Certified Beds, Provider Type, Provider Resides in Hospital, Date First Approved to Provide Medicare and Medicaid services, Continuing Care Retirement Community, Special Focus Facility, Most Recent Health Inspection More Than 2 Years Ago, Provider Changed Ownership in Last 12 Months, With a Resident and Family Council, Automatic Sprinkler Systems in All Required Areas, Overall Rating, Overall Rating Footnote, Health Inspection Rating, Health Inspection Rating Footnote, QM Rating, QM Rating Footnote, Staffing Rating, Staffing Rating Footnote, RN Staffing Rating, RN Staffing Rating Footnote, Reported Staffing Footnote, Physical Therapist Staffing Footnote, Reported CNA Staffing Hours per Resident per Day, Reported LPN Staffing Hours per Resident per Day, Reported RN Staffing Hours per Resident per Day, Reported Licensed Staffing Hours per Resident per Day, Reported Total Nurse Staffing Hours per Resident per Day, Reported Physical Therapist Staffing Hours per Resident Per Day, Expected CNA Staffing Hours per Resident per Day, Expected LPN Staffing Hours per Resident per Day, Expected RN Staffing Hours per Resident per Day, Expected Total Nurse Staffing Hours per Resident per Day, Adjusted CNA Staffing Hours per Resident per Day, Adjusted LPN Staffing Hours per Resident per Day, Adjusted RN Staffing Hours per Resident per Day, Adjusted Total Nurse Staffing Hours per Resident per Day, Cycle 1 Total Number of Health Deficiencies, Cycle 1 Number of Standard Health Deficiencies, Cycle 1 Number of Complaint Health Deficiencies, Cycle 1 Health Deficiency Score, Cycle 1 Standard Survey Health Date, Cycle 1 Number of Health Revisits, Cycle 1 Health Revisit Score, Cycle 1 Total Health Score, Cycle 2 Total Number of Health Deficiencies, Cycle 2 Number of Standard Health Deficiencies, Cycle 2 Number of Complaint Health Deficiencies, Cycle 2 Health Deficiency Score, Cycle 2 Standard Health Survey Date, Cycle 2 Number of Health Revisits, Cycle 2 Health Revisit Score, Cycle 2 Total Health Score, Cycle 3 Total Number of Health Deficiencies, Cycle 3 Number of Standard Health Deficiencies, Cycle 3 Number of Complaint Health Deficiencies, Cycle 3 Health Deficiency Score, Cycle 3 Standard Health Survey Date, Cycle 3 Number of Health Revisits, Cycle 3 Health Revisit Score, Cycle 3 Total Health Score, Total Weighted Health Survey Score, Number of Facility Reported Incidents, Number of Substantiated Complaints, Number of Fines, Total Amount of Fines in Dollars, Number of Payment Denials, Total Number of Penalties, Processing Date]
# Index: []
#
# [0 rows x 73 columns]

# %% [markdown]
# #### There are no duplicates

# %% [markdown]
# ## Dropping more unnecessary columns

# %%
# Dropping more unnecessary columns
df_nurs = df_nurs.drop(columns = ['QM Rating Footnote', 'Staffing Rating Footnote', 'RN Staffing Rating Footnote', 'Overall Rating Footnote', 'Health Inspection Rating Footnote', 'Physical Therapist Staffing Footnote'])

# %%
df_nurs.shape
# Out:
# (15050, 67)

# %%
df_nurs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15050 entries, 0 to 15632
# Data columns (total 67 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Federal Provider Number                                          15050 non-null  object
#  1   Provider Name                                                    15050 non-null  object
#  2   Provider State                                                   15050 non-null  object
#  3   Ownership Type                                                   15050 non-null  object
#  4   Number of Certified Beds                                         15050 non-null  int64
#  5   Number of Residents in Certified Beds                            15050 non-null  int64
#  6   Provider Type                                                    15050 non-null  object
#  7   Provider Resides in Hospital                                     15050 non-null  bool
#  8   Date First Approved to Provide Medicare and Medicaid services    15050 non-null  object
#  9   Continuing Care Retirement Community                             15050 non-null  bool
#  10  Special Focus Facility                                           15050 non-null  bool
#  11  Most Recent Health Inspection More Than 2 Years Ago              15050 non-null  bool
#  12  Provider Changed Ownership in Last 12 Months                     15050 non-null  bool
#  13  With a Resident and Family Council                               15050 non-null  object
#  14  Automatic Sprinkler Systems in All Required Areas                15050 non-null  object
#  15  Overall Rating                                                   15050 non-null  float64
#  16  Health Inspection Rating                                         15050 non-null  float64
#  17  QM Rating                                                        15050 non-null  float64
#  18  Staffing Rating                                                  15050 non-null  float64
#  19  RN Staffing Rating                                               15050 non-null  float64
#  20  Reported Staffing Footnote                                       15050 non-null  object
#  21  Reported CNA Staffing Hours per Resident per Day                 15050 non-null  float64
#  22  Reported LPN Staffing Hours per Resident per Day                 15050 non-null  float64
#  23  Reported RN Staffing Hours per Resident per Day                  15050 non-null  float64
#  24  Reported Licensed Staffing Hours per Resident per Day            15050 non-null  float64
#  25  Reported Total Nurse Staffing Hours per Resident per Day         15050 non-null  float64
#  26  Reported Physical Therapist Staffing Hours per Resident Per Day  15050 non-null  float64
#  27  Expected CNA Staffing Hours per Resident per Day                 15050 non-null  float64
#  28  Expected LPN Staffing Hours per Resident per Day                 15050 non-null  float64
#  29  Expected RN Staffing Hours per Resident per Day                  15050 non-null  float64
#  30  Expected Total Nurse Staffing Hours per Resident per Day         15050 non-null  float64
#  31  Adjusted CNA Staffing Hours per Resident per Day                 15050 non-null  float64
#  32  Adjusted LPN Staffing Hours per Resident per Day                 15050 non-null  float64
#  33  Adjusted RN Staffing Hours per Resident per Day                  15050 non-null  float64
#  34  Adjusted Total Nurse Staffing Hours per Resident per Day         15050 non-null  float64
#  35  Cycle 1 Total Number of Health Deficiencies                      15050 non-null  float64
#  36  Cycle 1 Number of Standard Health Deficiencies                   15050 non-null  float64
#  37  Cycle 1 Number of Complaint Health Deficiencies                  15050 non-null  float64
#  38  Cycle 1 Health Deficiency Score                                  15050 non-null  float64
#  39  Cycle 1 Standard Survey Health Date                              15050 non-null  object
#  40  Cycle 1 Number of Health Revisits                                15050 non-null  float64
#  41  Cycle 1 Health Revisit Score                                     15050 non-null  float64
#  42  Cycle 1 Total Health Score                                       15050 non-null  float64
#  43  Cycle 2 Total Number of Health Deficiencies                      15050 non-null  float64
#  44  Cycle 2 Number of Standard Health Deficiencies                   15050 non-null  float64
#  45  Cycle 2 Number of Complaint Health Deficiencies                  15050 non-null  float64
#  46  Cycle 2 Health Deficiency Score                                  15050 non-null  float64
#  47  Cycle 2 Standard Health Survey Date                              15050 non-null  object
#  48  Cycle 2 Number of Health Revisits                                15050 non-null  float64
#  49  Cycle 2 Health Revisit Score                                     15050 non-null  float64
#  50  Cycle 2 Total Health Score                                       15050 non-null  float64
#  51  Cycle 3 Total Number of Health Deficiencies                      15050 non-null  float64
#  52  Cycle 3 Number of Standard Health Deficiencies                   15050 non-null  float64
#  53  Cycle 3 Number of Complaint Health Deficiencies                  15050 non-null  float64
#  54  Cycle 3 Health Deficiency Score                                  15050 non-null  float64
#  55  Cycle 3 Standard Health Survey Date                              15050 non-null  object
#  56  Cycle 3 Number of Health Revisits                                15050 non-null  float64
#  57  Cycle 3 Health Revisit Score                                     15050 non-null  float64
#  58  Cycle 3 Total Health Score                                       15050 non-null  float64
#  59  Total Weighted Health Survey Score                               15050 non-null  float64
#  60  Number of Facility Reported Incidents                            15050 non-null  int64
#  61  Number of Substantiated Complaints                               15050 non-null  int64
#  62  Number of Fines                                                  15050 non-null  int64
#  63  Total Amount of Fines in Dollars                                 15050 non-null  object
#  64  Number of Payment Denials                                        15050 non-null  int64
#  65  Total Number of Penalties                                        15050 non-null  int64
#  66  Processing Date                                                  15050 non-null  object
# dtypes: bool(5), float64(41), int64(7), object(14)
# memory usage: 7.3+ MB

# %%
# Dropping more columns
df_nurs = df_nurs.drop(columns = ['Cycle 1 Number of Standard Health Deficiencies', 'Cycle 1 Number of Complaint Health Deficiencies', 'Cycle 2 Number of Standard Health Deficiencies', 'Cycle 2 Number of Complaint Health Deficiencies', 'Cycle 3 Number of Standard Health Deficiencies', 'Cycle 3 Number of Complaint Health Deficiencies', 'Reported CNA Staffing Hours per Resident per Day', 'Reported LPN Staffing Hours per Resident per Day', 'Reported RN Staffing Hours per Resident per Day', 'Reported Total Nurse Staffing Hours per Resident per Day', 'Expected CNA Staffing Hours per Resident per Day', 'Expected LPN Staffing Hours per Resident per Day', 'Expected RN Staffing Hours per Resident per Day', 'Expected Total Nurse Staffing Hours per Resident per Day', 'Total Amount of Fines in Dollars', 'Number of Payment Denials', 'Number of Fines'])

# %%
# Checking output
df_nurs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15050 entries, 0 to 15632
# Data columns (total 50 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Federal Provider Number                                          15050 non-null  object
#  1   Provider Name                                                    15050 non-null  object
#  2   Provider State                                                   15050 non-null  object
#  3   Ownership Type                                                   15050 non-null  object
#  4   Number of Certified Beds                                         15050 non-null  int64
#  5   Number of Residents in Certified Beds                            15050 non-null  int64
#  6   Provider Type                                                    15050 non-null  object
#  7   Provider Resides in Hospital                                     15050 non-null  bool
#  8   Date First Approved to Provide Medicare and Medicaid services    15050 non-null  object
#  9   Continuing Care Retirement Community                             15050 non-null  bool
#  10  Special Focus Facility                                           15050 non-null  bool
#  11  Most Recent Health Inspection More Than 2 Years Ago              15050 non-null  bool
#  12  Provider Changed Ownership in Last 12 Months                     15050 non-null  bool
#  13  With a Resident and Family Council                               15050 non-null  object
#  14  Automatic Sprinkler Systems in All Required Areas                15050 non-null  object
#  15  Overall Rating                                                   15050 non-null  float64
#  16  Health Inspection Rating                                         15050 non-null  float64
#  17  QM Rating                                                        15050 non-null  float64
#  18  Staffing Rating                                                  15050 non-null  float64
#  19  RN Staffing Rating                                               15050 non-null  float64
#  20  Reported Staffing Footnote                                       15050 non-null  object
#  21  Reported Licensed Staffing Hours per Resident per Day            15050 non-null  float64
#  22  Reported Physical Therapist Staffing Hours per Resident Per Day  15050 non-null  float64
#  23  Adjusted CNA Staffing Hours per Resident per Day                 15050 non-null  float64
#  24  Adjusted LPN Staffing Hours per Resident per Day                 15050 non-null  float64
#  25  Adjusted RN Staffing Hours per Resident per Day                  15050 non-null  float64
#  26  Adjusted Total Nurse Staffing Hours per Resident per Day         15050 non-null  float64
#  27  Cycle 1 Total Number of Health Deficiencies                      15050 non-null  float64
#  28  Cycle 1 Health Deficiency Score                                  15050 non-null  float64
#  29  Cycle 1 Standard Survey Health Date                              15050 non-null  object
#  30  Cycle 1 Number of Health Revisits                                15050 non-null  float64
#  31  Cycle 1 Health Revisit Score                                     15050 non-null  float64
#  32  Cycle 1 Total Health Score                                       15050 non-null  float64
#  33  Cycle 2 Total Number of Health Deficiencies                      15050 non-null  float64
#  34  Cycle 2 Health Deficiency Score                                  15050 non-null  float64
#  35  Cycle 2 Standard Health Survey Date                              15050 non-null  object
#  36  Cycle 2 Number of Health Revisits                                15050 non-null  float64
#  37  Cycle 2 Health Revisit Score                                     15050 non-null  float64
#  38  Cycle 2 Total Health Score                                       15050 non-null  float64
#  39  Cycle 3 Total Number of Health Deficiencies                      15050 non-null  float64
#  40  Cycle 3 Health Deficiency Score                                  15050 non-null  float64
#  41  Cycle 3 Standard Health Survey Date                              15050 non-null  object
#  42  Cycle 3 Number of Health Revisits                                15050 non-null  float64
#  43  Cycle 3 Health Revisit Score                                     15050 non-null  float64
#  44  Cycle 3 Total Health Score                                       15050 non-null  float64
#  45  Total Weighted Health Survey Score                               15050 non-null  float64
#  46  Number of Facility Reported Incidents                            15050 non-null  int64
#  47  Number of Substantiated Complaints                               15050 non-null  int64
#  48  Total Number of Penalties                                        15050 non-null  int64
#  49  Processing Date                                                  15050 non-null  object
# dtypes: bool(5), float64(27), int64(5), object(13)
# memory usage: 5.4+ MB

# %%
# Dropping more rows where 'Most Recent Health Inspection More Than 2 Years Ago' is 'True'
df_nurs = df_nurs.drop(df_nurs[df_nurs['Most Recent Health Inspection More Than 2 Years Ago'] == 'True'].index)

# %%
# Dropping column 'Most Recent Health Inspection More Than 2 Years Ago'
df_nurs = df_nurs.drop(columns = ['Most Recent Health Inspection More Than 2 Years Ago'])

# %%
# Dropping column 'Reported Staffing Footnote'
df_nurs = df_nurs.drop(columns = ['Reported Staffing Footnote'])

# %%
df_nurs.shape
# Out:
# (15050, 48)

# %%
df_nurs.describe()
# Out:
#        Number of Certified Beds  Number of Residents in Certified Beds  \
# count              15050.000000                           15050.000000
# mean                 107.529767                              87.949369
# std                   60.733675                              53.562887
# min                    4.000000                               3.000000
# 25%                   65.250000                              53.000000
# 50%                  100.000000                              80.000000
# 75%                  129.000000                             109.000000
# max                 1389.000000                             757.000000
#
#        Overall Rating  Health Inspection Rating     QM Rating  \
# count    15050.000000              15050.000000  15050.000000
# mean         3.145449                  2.795548      3.301595
# std          1.408625                  1.279367      1.402609
# min          1.000000                  1.000000      1.000000
# 25%          2.000000                  2.000000      2.000000
# 50%          3.000000                  3.000000      3.000000
# 75%          4.000000                  4.000000      5.000000
# max          5.000000                  5.000000      5.000000
#
#        Staffing Rating  RN Staffing Rating  \
# count     15050.000000        15050.000000
# mean          3.223721            3.400731
# std           1.154252            1.227094
# min           1.000000            1.000000
# 25%           3.000000            3.000000
# 50%           3.000000            3.000000
# 75%           4.000000            4.000000
# max           5.000000            5.000000
#
#        Reported Licensed Staffing Hours per Resident per Day  \
# count                                       15050.000000
# mean                                            1.683219
# std                                             0.704915
# min                                             0.228000
# 25%                                             1.333813
# 50%                                             1.557065
# 75%                                             1.839508
# max                                            20.788890
#
#        Reported Physical Therapist Staffing Hours per Resident Per Day  \
# count                                       15050.000000
# mean                                            0.100707
# std                                             0.132163
# min                                             0.000000
# 25%                                             0.034290
# 50%                                             0.070085
# 75%                                             0.120927
# max                                             3.320740
#
#        Adjusted CNA Staffing Hours per Resident per Day  ...  \
# count                                      15050.000000  ...
# mean                                           2.489698  ...
# std                                            0.679427  ...
# min                                            0.000000  ...
# 25%                                            2.085880  ...
# 50%                                            2.403195  ...
# 75%                                            2.795818  ...
# max                                           32.766640  ...
#
#        Cycle 2 Total Health Score  \
# count                15050.000000
# mean                    59.879734
# std                    105.591598
# min                      0.000000
# 25%                     16.000000
# 50%                     32.000000
# 75%                     64.000000
# max                   2144.000000
#
#        Cycle 3 Total Number of Health Deficiencies  \
# count                                 15050.000000
# mean                                      6.981528
# std                                       6.024541
# min                                       0.000000
# 25%                                       3.000000
# 50%                                       6.000000
# 75%                                      10.000000
# max                                      71.000000
#
#        Cycle 3 Health Deficiency Score  Cycle 3 Number of Health Revisits  \
# count                     15050.000000                       15050.000000
# mean                         54.220532                           0.909435
# std                          86.950084                           0.393951
# min                           0.000000                           0.000000
# 25%                          16.000000                           1.000000
# 50%                          32.000000                           1.000000
# 75%                          64.000000                           1.000000
# max                        1617.000000                           4.000000
#
#        Cycle 3 Health Revisit Score  Cycle 3 Total Health Score  \
# count                  15050.000000                15050.000000
# mean                       2.590565                   56.811096
# std                       23.074249                   98.513175
# min                        0.000000                    0.000000
# 25%                        0.000000                   16.000000
# 50%                        0.000000                   32.000000
# 75%                        0.000000                   64.000000
# max                     1132.000000                 2749.000000
#
#        Total Weighted Health Survey Score  \
# count                        15050.000000
# mean                            58.214577
# std                             69.840066
# min                              0.000000
# 25%                             20.000000
# 50%                             38.083500
# 75%                             70.000000
# max                           1014.500000
#
#        Number of Facility Reported Incidents  \
# count                           15050.000000
# mean                                1.045714
# std                                 2.787160
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 1.000000
# max                                96.000000
#
#        Number of Substantiated Complaints  Total Number of Penalties
# count                        15050.000000               15050.000000
# mean                             3.773821                   0.431827
# std                              6.707714                   0.912570
# min                              0.000000                   0.000000
# 25%                              0.000000                   0.000000
# 50%                              1.000000                   0.000000
# 75%                              5.000000                   1.000000
# max                            187.000000                  13.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# # 03. Export DataFrame as .csv file

# %%
# Exporting df_nurs as Project_Data_Checked.csv
df_nurs.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Project_Data_Checked1.csv'))
