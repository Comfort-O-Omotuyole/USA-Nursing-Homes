# %% [markdown]
# # 01. Import libraries and file

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# %matplotlib inline

# %%
# Define path
path = r'C:\Users\olufunsoo\Documents\CFProject'

# %%
# Import file 'Project_Data_Checked.csv' as df
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Project_Data_Updated_0311.csv'))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Federal Provider Number', 'Provider Name',
#        'Provider State', 'Ownership Type', 'Number of Certified Beds',
#        'Number of Residents in Certified Beds', 'Provider Type',
#        'Provider Resides in Hospital',
#        'Date First Approved to Provide Medicare and Medicaid services',
#        'Continuing Care Retirement Community', 'Special Focus Facility',
#        'Provider Changed Ownership in Last 12 Months',
#        'Automatic Sprinkler Systems in All Required Areas', 'Overall Rating',
#        'Health Inspection Rating', 'QM Rating', 'Staffing Rating',
#        'RN Staffing Rating',
#        'Reported Licensed Staffing Hours per Resident per Day',
#        'Reported Physical Therapist Staffing Hours per Resident Per Day',
#        'Adjusted CNA Staffing Hours per Resident per Day',
#        'Adjusted LPN Staffing Hours per Resident per Day',
#        'Adjusted RN Staffing Hours per Resident per Day',
# ...

# %%
# Creating subset
df_first = df[['Reported Physical Therapist Staffing Hours per Resident Per Day', 'RN Staffing Rating', 'Health Inspection Rating', 'Staffing Rating', 'QM Rating', 'Reported Licensed Staffing Hours per Resident per Day', 'Adjusted Total Nurse Staffing Hours per Resident per Day', 'Adjusted RN Staffing Hours per Resident per Day', 'Total Number of Penalties', 'Number of Certified Beds', 'Number of Residents in Certified Beds', 'Overall Rating', 'Number of Facility Reported Incidents', 'Number of Substantiated Complaints', 'Total Weighted Health Survey Score']]

# %%
df_first
# Out:
#       Nursing Home Age  \
# 0           15584 days
# 1           17130 days
# 2           14976 days
# 3           16683 days
# 4           15219 days
# ...                ...
# 15045        1458 days
# 15046        1049 days
# 15047         854 days
# 15048         877 days
# 15049         743 days
#
#        Reported Physical Therapist Staffing Hours per Resident Per Day  \
# 0                                                0.07696
# 1                                                0.09613
# 2                                                0.06234
# 3                                                0.00990
# 4                                                0.01049
# ...                                                  ...
# 15045                                            0.05227
# 15046                                            0.31216
# 15047                                            0.00000
# 15048                                            0.11796
# ...

# %%
# Checking the correlation of the variables in the subset
df_first.corr()
# Out:
#                                                     Reported Physical Therapist Staffing Hours per Resident Per Day  \
# Reported Physical Therapist Staffing Hours per ...                                           1.000000
# RN Staffing Rating                                                                           0.212752
# Health Inspection Rating                                                                     0.114116
# Staffing Rating                                                                              0.218842
# QM Rating                                                                                    0.101150
# Reported Licensed Staffing Hours per Resident p...                                           0.505565
# Adjusted Total Nurse Staffing Hours per Residen...                                           0.262608
# Adjusted RN Staffing Hours per Resident per Day                                              0.316184
# ...

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df_first.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.
